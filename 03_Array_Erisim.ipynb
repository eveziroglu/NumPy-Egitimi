# %% [markdown]
# # Dizi Elemanlarına Erişim
#
# NumPy dizileri ile çalışırken, elemanlara erişim, dizinin özelliklerini ve verilerini anlamak için çok önemlidir. Bu bölümde, dizilere erişim, dizinleme ve dilimleme işlemleri üzerinde duracağız.

# %% [markdown]
# ## Dizinleme (Indexing)
#
# Dizinin elemanlarına erişmek için dizinleri kullanırız. Dizi elemanları sıfırdan başlamaktadır, yani ilk elemanın indeksi 0'dır.
#
# Örnek:

# %%
import numpy as np

# Bir dizi oluşturalım
arr = np.array([10, 20, 30, 40, 50])

# İlk elemanı al
print(arr[0])  # Çıktı: 10

# Üçüncü elemanı al
print(arr[2])  # Çıktı: 30

# %% [markdown]
# ## Dilimleme (Slicing)
#
# Diziyi dilimlemek, bir dizi içindeki bir alt dizi elde etmemizi sağlar. Dilimleme işlemi, `:` operatörü kullanılarak yapılır.
#
# Örnek:

# %%
# Bir dizi oluşturalım
dilimi = arr[1:4]  # 1. indeksten 4. indise kadar (4 dahil değil)
print(dilimi)  # Çıktı: [20 30 40] 

# İlk iki eleman
print(arr[:2])  # Çıktı: [10 20] 

# Son iki elemanı al
print(arr[-2:])  # Çıktı: [40 50]

# %% [markdown]
# ## Sonuç
#
# Dizi elemanlarına erişim, dizinleme ve dilimleme, NumPy kütüphanesi ile çalışırken temel işlemlerdir. Bu işlemler sayesinde diziler üzerinde rahatça çalışabiliriz.
